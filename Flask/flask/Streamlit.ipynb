# %% [markdown]
# ## Introduction to StreamLit
# open source app framework to make web machine learning apps

# %%
pip install streamlit
# Out:
# Collecting streamlit
#   Downloading streamlit-1.41.1-py2.py3-none-any.whl.metadata (8.5 kB)
# Collecting altair<6,>=4.0 (from streamlit)
#   Downloading altair-5.5.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: blinker<2,>=1.0.0 in d:\datasciencebootcamp\python\venv\lib\site-packages (from streamlit) (1.9.0)
# Collecting cachetools<6,>=4.0 (from streamlit)
#   Downloading cachetools-5.5.0-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: click<9,>=7.0 in d:\datasciencebootcamp\python\venv\lib\site-packages (from streamlit) (8.1.8)
# Requirement already satisfied: numpy<3,>=1.23 in d:\datasciencebootcamp\python\venv\lib\site-packages (from streamlit) (2.2.1)
# Requirement already satisfied: packaging<25,>=20 in d:\datasciencebootcamp\python\venv\lib\site-packages (from streamlit) (24.2)
# Requirement already satisfied: pandas<3,>=1.4.0 in d:\datasciencebootcamp\python\venv\lib\site-packages (from streamlit) (2.2.3)
# Requirement already satisfied: pillow<12,>=7.1.0 in d:\datasciencebootcamp\python\venv\lib\site-packages (from streamlit) (11.1.0)
# Collecting protobuf<6,>=3.20 (from streamlit)
#   Downloading protobuf-5.29.3-cp310-abi3-win_amd64.whl.metadata (592 bytes)
# Collecting pyarrow>=7.0 (from streamlit)
#   Downloading pyarrow-19.0.0-cp312-cp312-win_amd64.whl.metadata (3.4 kB)
# Collecting requests<3,>=2.27 (from streamlit)
#   Downloading requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting rich<14,>=10.14.0 (from streamlit)
#   Downloading rich-13.9.4-py3-none-any.whl.metadata (18 kB)
# Collecting tenacity<10,>=8.1.0 (from streamlit)
#   Downloading tenacity-9.0.0-py3-none-any.whl.metadata (1.2 kB)
# Collecting toml<2,>=0.10.1 (from streamlit)
#   Downloading toml-0.10.2-py2.py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in d:\datasciencebootcamp\python\venv\lib\site-packages (from streamlit) (4.12.2)
# Collecting watchdog<7,>=2.1.5 (from streamlit)
#   Downloading watchdog-6.0.0-py3-none-win_amd64.whl.metadata (44 kB)
# Collecting gitpython!=3.1.19,<4,>=3.0.7 (from streamlit)
#   Downloading GitPython-3.1.44-py3-none-any.whl.metadata (13 kB)
# Collecting pydeck<1,>=0.8.0b4 (from streamlit)
#   Downloading pydeck-0.9.1-py2.py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: tornado<7,>=6.0.3 in d:\datasciencebootcamp\python\venv\lib\site-packages (from streamlit) (6.4.2)
# Requirement already satisfied: jinja2 in d:\datasciencebootcamp\python\venv\lib\site-packages (from altair<6,>=4.0->streamlit) (3.1.5)
# Collecting jsonschema>=3.0 (from altair<6,>=4.0->streamlit)
#   Downloading jsonschema-4.23.0-py3-none-any.whl.metadata (7.9 kB)
# Collecting narwhals>=1.14.2 (from altair<6,>=4.0->streamlit)
#   Downloading narwhals-1.23.0-py3-none-any.whl.metadata (10.0 kB)
# Requirement already satisfied: colorama in d:\datasciencebootcamp\python\venv\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Collecting gitdb<5,>=4.0.1 (from gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Downloading gitdb-4.0.12-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\datasciencebootcamp\python\venv\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\datasciencebootcamp\python\venv\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\datasciencebootcamp\python\venv\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2024.2)
# Collecting charset-normalizer<4,>=2 (from requests<3,>=2.27->streamlit)
#   Downloading charset_normalizer-3.4.1-cp312-cp312-win_amd64.whl.metadata (36 kB)
# Collecting idna<4,>=2.5 (from requests<3,>=2.27->streamlit)
#   Downloading idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting urllib3<3,>=1.21.1 (from requests<3,>=2.27->streamlit)
#   Downloading urllib3-2.3.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests<3,>=2.27->streamlit)
#   Downloading certifi-2024.12.14-py3-none-any.whl.metadata (2.3 kB)
# Collecting markdown-it-py>=2.2.0 (from rich<14,>=10.14.0->streamlit)
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in d:\datasciencebootcamp\python\venv\lib\site-packages (from rich<14,>=10.14.0->streamlit) (2.18.0)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Downloading smmap-5.0.2-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\datasciencebootcamp\python\venv\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit) (3.0.2)
# Collecting attrs>=22.2.0 (from jsonschema>=3.0->altair<6,>=4.0->streamlit)
#   Downloading attrs-24.3.0-py3-none-any.whl.metadata (11 kB)
# Collecting jsonschema-specifications>=2023.03.6 (from jsonschema>=3.0->altair<6,>=4.0->streamlit)
#   Downloading jsonschema_specifications-2024.10.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting referencing>=0.28.4 (from jsonschema>=3.0->altair<6,>=4.0->streamlit)
#   Downloading referencing-0.36.1-py3-none-any.whl.metadata (2.8 kB)
# Collecting rpds-py>=0.7.1 (from jsonschema>=3.0->altair<6,>=4.0->streamlit)
#   Downloading rpds_py-0.22.3-cp312-cp312-win_amd64.whl.metadata (4.2 kB)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: six>=1.5 in d:\datasciencebootcamp\python\venv\lib\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.17.0)
# Downloading streamlit-1.41.1-py2.py3-none-any.whl (9.1 MB)
#    ---------------------------------------- 0.0/9.1 MB ? eta -:--:--
#    ----------- ---------------------------- 2.6/9.1 MB 13.8 MB/s eta 0:00:01
#    --------------------- ------------------ 5.0/9.1 MB 12.6 MB/s eta 0:00:01
#    -------------------------------- ------- 7.3/9.1 MB 11.9 MB/s eta 0:00:01
#    ---------------------------------------- 9.1/9.1 MB 11.3 MB/s eta 0:00:00
# Downloading altair-5.5.0-py3-none-any.whl (731 kB)
#    ---------------------------------------- 0.0/731.2 kB ? eta -:--:--
#    --------------------------------------- 731.2/731.2 kB 10.0 MB/s eta 0:00:00
# Downloading cachetools-5.5.0-py3-none-any.whl (9.5 kB)
# Downloading GitPython-3.1.44-py3-none-any.whl (207 kB)
# Downloading protobuf-5.29.3-cp310-abi3-win_amd64.whl (434 kB)
# Downloading pyarrow-19.0.0-cp312-cp312-win_amd64.whl (25.2 MB)
#    ---------------------------------------- 0.0/25.2 MB ? eta -:--:--
#    --- ------------------------------------ 2.4/25.2 MB 12.2 MB/s eta 0:00:02
#    ------- -------------------------------- 4.5/25.2 MB 10.8 MB/s eta 0:00:02
#    ---------- ----------------------------- 6.6/25.2 MB 10.3 MB/s eta 0:00:02
#    ------------- -------------------------- 8.4/25.2 MB 10.2 MB/s eta 0:00:02
#    ----------------- ---------------------- 10.7/25.2 MB 10.2 MB/s eta 0:00:02
#    -------------------- ------------------- 12.8/25.2 MB 10.2 MB/s eta 0:00:02
#    ------------------------ --------------- 15.2/25.2 MB 10.3 MB/s eta 0:00:01
#    --------------------------- ------------ 17.6/25.2 MB 10.4 MB/s eta 0:00:01
#    ------------------------------- -------- 19.9/25.2 MB 10.7 MB/s eta 0:00:01
#    ------------------------------------ --- 22.8/25.2 MB 10.8 MB/s eta 0:00:01
#    ---------------------------------------  25.2/25.2 MB 11.0 MB/s eta 0:00:01
#    ---------------------------------------- 25.2/25.2 MB 10.8 MB/s eta 0:00:00
# Downloading pydeck-0.9.1-py2.py3-none-any.whl (6.9 MB)
#    ---------------------------------------- 0.0/6.9 MB ? eta -:--:--
#    ------------- -------------------------- 2.4/6.9 MB 12.3 MB/s eta 0:00:01
#    ---------------------- ----------------- 3.9/6.9 MB 9.4 MB/s eta 0:00:01
#    ------------------------------- -------- 5.5/6.9 MB 8.6 MB/s eta 0:00:01
#    ---------------------------------------- 6.9/6.9 MB 8.3 MB/s eta 0:00:00
# Downloading requests-2.32.3-py3-none-any.whl (64 kB)
# Downloading rich-13.9.4-py3-none-any.whl (242 kB)
# Downloading tenacity-9.0.0-py3-none-any.whl (28 kB)
# Downloading toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Downloading watchdog-6.0.0-py3-none-win_amd64.whl (79 kB)
# Downloading certifi-2024.12.14-py3-none-any.whl (164 kB)
# Downloading charset_normalizer-3.4.1-cp312-cp312-win_amd64.whl (102 kB)
# Downloading gitdb-4.0.12-py3-none-any.whl (62 kB)
# Downloading idna-3.10-py3-none-any.whl (70 kB)
# Downloading jsonschema-4.23.0-py3-none-any.whl (88 kB)
# Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Downloading narwhals-1.23.0-py3-none-any.whl (306 kB)
# Downloading urllib3-2.3.0-py3-none-any.whl (128 kB)
# Downloading attrs-24.3.0-py3-none-any.whl (63 kB)
# Downloading jsonschema_specifications-2024.10.1-py3-none-any.whl (18 kB)
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Downloading referencing-0.36.1-py3-none-any.whl (26 kB)
# Downloading rpds_py-0.22.3-cp312-cp312-win_amd64.whl (235 kB)
# Downloading smmap-5.0.2-py3-none-any.whl (24 kB)
# Installing collected packages: watchdog, urllib3, toml, tenacity, smmap, rpds-py, pyarrow, protobuf, narwhals, mdurl, idna, charset-normalizer, certifi, cachetools, attrs, requests, referencing, pydeck, markdown-it-py, gitdb, rich, jsonschema-specifications, gitpython, jsonschema, altair, streamlit
# Successfully installed altair-5.5.0 attrs-24.3.0 cachetools-5.5.0 certifi-2024.12.14 charset-normalizer-3.4.1 gitdb-4.0.12 gitpython-3.1.44 idna-3.10 jsonschema-4.23.0 jsonschema-specifications-2024.10.1 markdown-it-py-3.0.0 mdurl-0.1.2 narwhals-1.23.0 protobuf-5.29.3 pyarrow-19.0.0 pydeck-0.9.1 referencing-0.36.1 requests-2.32.3 rich-13.9.4 rpds-py-0.22.3 smmap-5.0.2 streamlit-1.41.1 tenacity-9.0.0 toml-0.10.2 urllib3-2.3.0 watchdog-6.0.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import streamlit as st
import pandas as pd
import numpy as np
## Title of the application
st.title("Hello StreamLit")

## Display a simple text
st.write("This is a simple text")
# Out:
# 2025-01-22 00:43:09.572 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-22 00:43:09.949
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run d:\DataScienceBootCamp\python\venv\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2025-01-22 00:43:09.949 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-22 00:43:09.950 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-22 00:43:09.950 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-22 00:43:09.950 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-22 00:43:09.952 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
